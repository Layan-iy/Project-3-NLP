# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import normalize
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import tensorflow_datasets as tfds


df = pd.read_csv("Combined_DataFrame.csv")



# Load custom dataset
def load_custom_dataset(max_samples=25000):
    # Prétraitement des données
    def preprocess_text(text, label):
        return text, int(label)

    # Données d'entraînement
    train_reviews = []
    train_labels = []
    for text, label in zip(df['train_reviews'].iloc[:max_samples], df['train_labels'].iloc[:max_samples]):
        review, sentiment = preprocess_text(text, label)
        train_reviews.append(review)
        train_labels.append(sentiment)

    # Données de test
    test_reviews = []
    test_labels = []
    for text, label in zip(df['test_reviews'].iloc[:max_samples // 5], df['test_labels'].iloc[:max_samples // 5]):
        review, sentiment = preprocess_text(text, label)
        test_reviews.append(review)
        test_labels.append(sentiment)

    return train_reviews, train_labels, test_reviews, test_labels

# Federated Learning Server
class FederatedServer:
    def __init__(self, num_clients, initial_lr=0.1):
        self.num_clients = num_clients
        self.global_model = None
        self.vectorizer = TfidfVectorizer(max_features=5000)
        self.clients = []
        self.learning_rate = initial_lr

    def initialize_model(self, X):
        self.vectorizer.fit(X)
        vocab_size = len(self.vectorizer.get_feature_names_out())
        self.global_model = LogisticRegression(warm_start=True, max_iter=1000, C=1.0, solver='lbfgs')
        self.global_model.classes_ = np.array([0, 1])
        self.global_model.coef_ = np.random.randn(1, vocab_size)
        self.global_model.intercept_ = np.random.randn(1)

    def aggregate_models(self):
        client_coefs = []
        client_intercepts = []
        for client in self.clients:
            client_coefs.append(client.model.coef_)
            client_intercepts.append(client.model.intercept_)

        new_coef = np.mean(client_coefs, axis=0)
        new_intercept = np.mean(client_intercepts, axis=0)

        self.global_model.coef_ = self.global_model.coef_ + self.learning_rate * (new_coef - self.global_model.coef_)
        self.global_model.intercept_ = self.global_model.intercept_ + self.learning_rate * (new_intercept - self.global_model.intercept_)

    def distribute_model(self):
        for client in self.clients:
            client.update_model(self.global_model)

    def decay_learning_rate(self, decay_factor=0.95):
        self.learning_rate *= decay_factor

# Federated Learning Client
class FederatedClient:
    def __init__(self, client_id, X, y, server):
        self.client_id = client_id
        self.X = X
        self.y = y
        self.server = server
        self.model = None

    def preprocess_data(self):
        self.X_vec = self.server.vectorizer.transform(self.X)
        self.X_vec = normalize(self.X_vec, norm='l2', axis=1)

    def train(self, epochs=5):
        if self.model is None:
            self.model = LogisticRegression(warm_start=True, max_iter=1000, C=1.0, solver='lbfgs')
            self.model.classes_ = np.array([0, 1])
            self.model.coef_ = self.server.global_model.coef_.copy()
            self.model.intercept_ = self.server.global_model.intercept_.copy()

        for _ in range(epochs):
            self.model.fit(self.X_vec, self.y)

    def update_model(self, global_model):
        self.model.coef_ = global_model.coef_.copy()
        self.model.intercept_ = global_model.intercept_.copy()

# Non-uniform data distribution
def distribute_data_non_uniform(X, y, num_clients):
    client_data = []
    class_indices = [np.where(y == c)[0] for c in np.unique(y)]

    for i in range(num_clients):
        client_indices = []
        for class_idx in class_indices:
            proportion = np.random.beta(2, 5)
            num_samples = int(proportion * len(class_idx))
            client_indices.extend(np.random.choice(class_idx, num_samples, replace=False))

        client_X = [X[j] for j in client_indices]
        client_y = [y[j] for j in client_indices]
        client_data.append((client_X, client_y))

    return client_data

# Main federated learning process
def run_federated_learning(num_clients, num_rounds, train_reviews, train_labels, test_reviews, test_labels):
    server = FederatedServer(num_clients)

    client_data = distribute_data_non_uniform(train_reviews, train_labels, num_clients)

    for i, (X, y) in enumerate(client_data):
        client = FederatedClient(i, X, y, server)
        server.clients.append(client)

    server.initialize_model(train_reviews)

    for client in server.clients:
        client.preprocess_data()

    global_metrics = {'accuracy': [], 'f1': [], 'precision': [], 'recall': []}
    client_accuracies = [[] for _ in range(num_clients)]

    for round in range(num_rounds):
        print(f"Round {round + 1}/{num_rounds}")

        for client in server.clients:
            client.train()

        server.aggregate_models()
        server.distribute_model()
        server.decay_learning_rate()

        X_test_vec = server.vectorizer.transform(test_reviews)
        X_test_vec = normalize(X_test_vec, norm='l2', axis=1)
        global_preds = server.global_model.predict(X_test_vec)

        global_metrics['accuracy'].append(accuracy_score(test_labels, global_preds))
        global_metrics['f1'].append(f1_score(test_labels, global_preds, average='weighted'))
        global_metrics['precision'].append(precision_score(test_labels, global_preds, average='weighted'))
        global_metrics['recall'].append(recall_score(test_labels, global_preds, average='weighted'))

        for i, client in enumerate(server.clients):
            client_accuracy = accuracy_score(client.y, client.model.predict(client.X_vec))
            client_accuracies[i].append(client_accuracy)

        print(f"Global model accuracy: {global_metrics['accuracy'][-1]:.4f}, F1 score: {global_metrics['f1'][-1]:.4f}")

    return server, global_metrics, client_accuracies

# Run federated learning
num_rounds = 50
client_numbers = [3, 5, 10]
all_global_metrics = []
all_client_accuracies = []



train_reviews, train_labels, test_reviews, test_labels = load_custom_dataset()

for num_clients in client_numbers:
    print(f"\nRunning federated learning with {num_clients} clients")
    server, global_metrics, client_accuracies = run_federated_learning(num_clients, num_rounds, train_reviews, train_labels, test_reviews, test_labels)
    all_global_metrics.append(global_metrics)
    all_client_accuracies.append(client_accuracies)

# Centralized model for comparison
centralized_model = LogisticRegression(max_iter=1000)
X_train_vec = server.vectorizer.transform(train_reviews)
X_train_vec = normalize(X_train_vec, norm='l2', axis=1)
centralized_model.fit(X_train_vec, train_labels)

X_test_vec = server.vectorizer.transform(test_reviews)
X_test_vec = normalize(X_test_vec, norm='l2', axis=1)
centralized_accuracy = accuracy_score(test_labels, centralized_model.predict(X_test_vec))

# Visualizations
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")
colors = sns.color_palette("deep", n_colors=max(client_numbers))

# 1. Privacy preservation visualization
fig, ax = plt.subplots(figsize=(12, 8))
client_data_sizes = [len(client.X) for client in server.clients]
total_data = sum(client_data_sizes)

ax.bar(range(1, len(client_data_sizes) + 1), client_data_sizes, color=colors)
ax.set_xlabel('Client', fontsize=14)
ax.set_ylabel('Number of Reviews', fontsize=14)
ax.set_title('Data Distribution Among Clients\nShowcasing Privacy Preservation', fontsize=18)
ax.text(0.5, -0.15, f'Each client keeps their data locally, processing only {client_data_sizes[0]/total_data:.1%} of total data on average',
        horizontalalignment='center', verticalalignment='center', transform=ax.transAxes, fontsize=12)

for i, v in enumerate(client_data_sizes):
    ax.text(i+1, v, str(v), ha='center', va='bottom')

ax.grid(False)
plt.tight_layout()
plt.savefig('privacy_preservation.png', dpi=300, bbox_inches='tight')
#plt.close()

# 2. Model performance comparison
fig, ax = plt.subplots(figsize=(12, 8))
x = np.arange(len(client_numbers))
width = 0.35

centralized_accuracies = [centralized_accuracy for _ in client_numbers]
federated_accuracies = [global_metrics['accuracy'][-1] for global_metrics in all_global_metrics]

rects1 = ax.bar(x - width/2, centralized_accuracies, width, label='Centralized', color=colors[0])
rects2 = ax.bar(x + width/2, federated_accuracies, width, label='Federated', color=colors[1])

ax.set_xlabel('Number of Clients', fontsize=14)
ax.set_ylabel('Accuracy', fontsize=14)
ax.set_title('Centralized vs Federated Learning Performance', fontsize=18)
ax.set_xticks(x)
ax.set_xticklabels(client_numbers)
ax.legend(fontsize=12)

ax.bar_label(rects1, padding=3, fmt='%.3f')
ax.bar_label(rects2, padding=3, fmt='%.3f')

ax.grid(False)
plt.tight_layout()
plt.savefig('performance_comparison.png', dpi=300, bbox_inches='tight')
#plt.close()

# 3. Communication efficiency
fig, ax = plt.subplots(figsize=(12, 8))

for i, client_num in enumerate(client_numbers):
    ax.plot(range(1, num_rounds + 1), all_global_metrics[i]['accuracy'],
            label=f'{client_num} clients ({sum(len(client.X) for client in server.clients)} reviews)',
            color=colors[i], linewidth=2)

ax.set_xlabel('Communication Rounds', fontsize=14)
ax.set_ylabel('Global Model Accuracy', fontsize=14)
ax.set_title('Communication Efficiency in Federated Learning', fontsize=18)
ax.legend(fontsize=12)

ax.grid(False)
plt.tight_layout()
plt.savefig('communication_efficiency.png', dpi=300, bbox_inches='tight')
#plt.close()

# 4. Model convergence across clients
fig, ax = plt.subplots(figsize=(12, 8))

for i, accuracies in enumerate(all_client_accuracies[-1]):
    ax.plot(range(1, num_rounds + 1), accuracies,
            label=f'Client {i+1} ({len(server.clients[i].X)} reviews)',
            color=colors[i], alpha=0.7, linewidth=2)

ax.plot(range(1, num_rounds + 1), all_global_metrics[-1]['accuracy'],
        label=f'Global Model ({sum(len(client.X) for client in server.clients)} total reviews)',
        color='black', linewidth=3)

ax.set_xlabel('Rounds', fontsize=14)
ax.set_ylabel('Accuracy', fontsize=14)
ax.set_title('Model Convergence Across Clients', fontsize=18)
ax.legend(fontsize=12, bbox_to_anchor=(1.05, 1), loc='upper left')

ax.grid(False)
plt.tight_layout()
plt.savefig('model_convergence.png', dpi=300, bbox_inches='tight')
#plt.close()

# 5. Data heterogeneity handling
fig, ax = plt.subplots(figsize=(12, 8))

client_class_distributions = []
for client in server.clients:
    class_dist = np.bincount(client.y) / len(client.y)
    client_class_distributions.append(class_dist)

client_class_distributions = np.array(client_class_distributions)
sns.heatmap(client_class_distributions, annot=True, fmt='.2f', cmap='YlGnBu', ax=ax)

ax.set_xlabel('Class', fontsize=14)
ax.set_ylabel('Client', fontsize=14)
ax.set_title('Data Heterogeneity Across Clients', fontsize=18)

plt.tight_layout()
plt.savefig('data_heterogeneity.png', dpi=300, bbox_inches='tight')
#plt.close()

print("Visualizations have been saved as PNG files.")
# Out:
# Running federated learning with 3 clients
# Round 1/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.6548, F1 score: 0.7914
# Round 2/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.7226, F1 score: 0.8390
# Round 3/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.7874, F1 score: 0.8811
# Round 4/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.8366, F1 score: 0.9110
# Round 5/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.8792, F1 score: 0.9357
# Round 6/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9126, F1 score: 0.9543
# Round 7/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9348, F1 score: 0.9663
# Round 8/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9470, F1 score: 0.9728
# Round 9/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9566, F1 score: 0.9778
# Round 10/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9638, F1 score: 0.9816
# Round 11/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9682, F1 score: 0.9838
# Round 12/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9718, F1 score: 0.9857
# Round 13/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9770, F1 score: 0.9884
# Round 14/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9802, F1 score: 0.9900
# Round 15/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9820, F1 score: 0.9909
# Round 16/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9828, F1 score: 0.9913
# Round 17/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9840, F1 score: 0.9919
# Round 18/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9848, F1 score: 0.9923
# Round 19/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9854, F1 score: 0.9926
# Round 20/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9864, F1 score: 0.9932
# Round 21/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9872, F1 score: 0.9936
# Round 22/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9872, F1 score: 0.9936
# Round 23/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9874, F1 score: 0.9937
# Round 24/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9882, F1 score: 0.9941
# Round 25/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9884, F1 score: 0.9942
# Round 26/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9886, F1 score: 0.9943
# Round 27/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9888, F1 score: 0.9944
# Round 28/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9886, F1 score: 0.9943
# Round 29/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9886, F1 score: 0.9943
# Round 30/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9886, F1 score: 0.9943
# Round 31/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9888, F1 score: 0.9944
# Round 32/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9890, F1 score: 0.9945
# Round 33/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9890, F1 score: 0.9945
# Round 34/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9892, F1 score: 0.9946
# Round 35/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9894, F1 score: 0.9947
# Round 36/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9896, F1 score: 0.9948
# Round 37/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9894, F1 score: 0.9947
# Round 38/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9894, F1 score: 0.9947
# Round 39/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9896, F1 score: 0.9948
# Round 40/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9898, F1 score: 0.9949
# Round 41/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9900, F1 score: 0.9950
# Round 42/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9902, F1 score: 0.9951
# Round 43/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9902, F1 score: 0.9951
# Round 44/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9902, F1 score: 0.9951
# Round 45/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9902, F1 score: 0.9951
# Round 46/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9902, F1 score: 0.9951
# Round 47/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9902, F1 score: 0.9951
# Round 48/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9902, F1 score: 0.9951
# Round 49/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9904, F1 score: 0.9952
# Round 50/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9904, F1 score: 0.9952
#
# Running federated learning with 5 clients
# Round 1/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9674, F1 score: 0.9834
# Round 2/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9708, F1 score: 0.9852
# Round 3/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9710, F1 score: 0.9853
# Round 4/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9710, F1 score: 0.9853
# Round 5/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9694, F1 score: 0.9845
# Round 6/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9652, F1 score: 0.9823
# Round 7/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9636, F1 score: 0.9815
# Round 8/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9606, F1 score: 0.9799
# Round 9/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9570, F1 score: 0.9780
# Round 10/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9518, F1 score: 0.9753
# Round 11/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9474, F1 score: 0.9730
# Round 12/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9428, F1 score: 0.9706
# Round 13/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9378, F1 score: 0.9679
# Round 14/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9334, F1 score: 0.9656
# Round 15/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9302, F1 score: 0.9638
# Round 16/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9264, F1 score: 0.9618
# Round 17/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9240, F1 score: 0.9605
# Round 18/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9202, F1 score: 0.9584
# Round 19/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9160, F1 score: 0.9562
# Round 20/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9134, F1 score: 0.9547
# Round 21/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9096, F1 score: 0.9527
# Round 22/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9068, F1 score: 0.9511
# Round 23/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9042, F1 score: 0.9497
# Round 24/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.9016, F1 score: 0.9483
# Round 25/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.8988, F1 score: 0.9467
# Round 26/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.8966, F1 score: 0.9455
# Round 27/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.8952, F1 score: 0.9447
# Round 28/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.8922, F1 score: 0.9430
# Round 29/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.8904, F1 score: 0.9420
# Round 30/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.8882, F1 score: 0.9408
# Round 31/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.8862, F1 score: 0.9397
# Round 32/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.8854, F1 score: 0.9392
# Round 33/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.8834, F1 score: 0.9381
# Round 34/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.8822, F1 score: 0.9374
# Round 35/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.8806, F1 score: 0.9365
# Round 36/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.8794, F1 score: 0.9358
# Round 37/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.8788, F1 score: 0.9355
# Round 38/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.8772, F1 score: 0.9346
# Round 39/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.8766, F1 score: 0.9342
# Round 40/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.8742, F1 score: 0.9329
# Round 41/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.8730, F1 score: 0.9322
# Round 42/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.8720, F1 score: 0.9316
# Round 43/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.8712, F1 score: 0.9312
# Round 44/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.8712, F1 score: 0.9312
# Round 45/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.8706, F1 score: 0.9308
# Round 46/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.8702, F1 score: 0.9306
# Round 47/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.8694, F1 score: 0.9301
# Round 48/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.8686, F1 score: 0.9297
# Round 49/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.8684, F1 score: 0.9296
# Round 50/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.8678, F1 score: 0.9292
#
# Running federated learning with 10 clients
# Round 1/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.0298, F1 score: 0.0579
# Round 2/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.0382, F1 score: 0.0736
# Round 3/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.0558, F1 score: 0.1057
# Round 4/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.0824, F1 score: 0.1523
# Round 5/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.1078, F1 score: 0.1946
# Round 6/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.1466, F1 score: 0.2557
# Round 7/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.1854, F1 score: 0.3128
# Round 8/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.2268, F1 score: 0.3697
# Round 9/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.2688, F1 score: 0.4237
# Round 10/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.3112, F1 score: 0.4747
# Round 11/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.3468, F1 score: 0.5150
# Round 12/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.3824, F1 score: 0.5532
# Round 13/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.4218, F1 score: 0.5933
# Round 14/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.4520, F1 score: 0.6226
# Round 15/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.4814, F1 score: 0.6499
# Round 16/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.5096, F1 score: 0.6751
# Round 17/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.5286, F1 score: 0.6916
# Round 18/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.5470, F1 score: 0.7072
# Round 19/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.5650, F1 score: 0.7220
# Round 20/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.5784, F1 score: 0.7329
# Round 21/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.5952, F1 score: 0.7462
# Round 22/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.6114, F1 score: 0.7588
# Round 23/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.6234, F1 score: 0.7680
# Round 24/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.6316, F1 score: 0.7742
# Round 25/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.6388, F1 score: 0.7796
# Round 26/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.6446, F1 score: 0.7839
# Round 27/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.6490, F1 score: 0.7871
# Round 28/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.6548, F1 score: 0.7914
# Round 29/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.6620, F1 score: 0.7966
# Round 30/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.6668, F1 score: 0.8001
# Round 31/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.6728, F1 score: 0.8044
# Round 32/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.6780, F1 score: 0.8081
# Round 33/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.6820, F1 score: 0.8109
# Round 34/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.6848, F1 score: 0.8129
# Round 35/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.6880, F1 score: 0.8152
# Round 36/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.6916, F1 score: 0.8177
# Round 37/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.6956, F1 score: 0.8205
# Round 38/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.6976, F1 score: 0.8219
# Round 39/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.6996, F1 score: 0.8233
# Round 40/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.7032, F1 score: 0.8257
# Round 41/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.7046, F1 score: 0.8267
# Round 42/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.7074, F1 score: 0.8286
# Round 43/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.7104, F1 score: 0.8307
# Round 44/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.7118, F1 score: 0.8316
# Round 45/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.7126, F1 score: 0.8322
# Round 46/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.7134, F1 score: 0.8327
# Round 47/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.7144, F1 score: 0.8334
# Round 48/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.7156, F1 score: 0.8342
# Round 49/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.7168, F1 score: 0.8350
# Round 50/50
# C:\Users\layan\.jdks\miniforge\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Global model accuracy: 0.7182, F1 score: 0.8360
# Visualizations have been saved as PNG files.
